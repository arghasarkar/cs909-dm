# %% [markdown]
# # RNN for Time Series Prediction
#
# This is a time series prediction task. You are given a dataset which reports on the weather and the level of pollution each hour for five years, and asked to train Recurrent Neural Networks (RNNs) to predict the hourly pollution level.

# %%
import numpy as np 
import pandas as pd 
import math
from datetime import datetime
import matplotlib.pyplot as plt # visualizing data
import seaborn as sns 
from collections import Counter

from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization

# %matplotlib inline
# Out:
# D:\Applications\Python3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## a) Load the data from the file. Perform necessary pre-processing (e.g., missing value replacement, uninformative attribute removal, etc.) and visualise the values of various attributes over the five-year period.

# %%
import os
import sys

# write your code here
DATA_DIR = './data/'
FILENAME = "pollution.csv"
FILE_PATH = os.path.abspath(os.path.join(DATA_DIR, FILENAME))
# print(FILE_PATH)

pollution_df = pd.read_csv(FILE_PATH, index_col="No")

# %%
HEAD_COUNT = 10

pollution_df.head(HEAD_COUNT)
# Out:
#     year  month  day  hour  pm2.5  Dew  Temperature  Pressure Wind_Direction  \
# No
# 1   2010      1    1     0    NaN  -21        -11.0    1021.0             NW
# 2   2010      1    1     1    NaN  -21        -12.0    1020.0             NW
# 3   2010      1    1     2    NaN  -21        -11.0    1019.0             NW
# 4   2010      1    1     3    NaN  -21        -14.0    1019.0             NW
# 5   2010      1    1     4    NaN  -20        -12.0    1018.0             NW
# 6   2010      1    1     5    NaN  -19        -10.0    1017.0             NW
# 7   2010      1    1     6    NaN  -19         -9.0    1017.0             NW
# 8   2010      1    1     7    NaN  -19         -9.0    1017.0             NW
# 9   2010      1    1     8    NaN  -19         -9.0    1017.0             NW
# 10  2010      1    1     9    NaN  -20         -8.0    1017.0             NW
#
#     Wind_Speed  Snow  Rain
# No
# 1         1.79     0     0
# 2         4.92     0     0
# 3         6.71     0     0
# 4         9.84     0     0
# 5        12.97     0     0
# 6        16.10     0     0
# 7        19.23     0     0
# 8        21.02     0     0
# 9        24.15     0     0
# 10       27.28     0     0

# %% [markdown]
# Over here, I have dropped the month, day and the hour. Converted the time information into a new variable called **datetime**. The information was dropped as it does not give us any insight into the pollution information. Intuitively, the pollution level is not dependent on time but rather on the weather conditions.
#
# It could be argued that the weather is dependent on time as the temperature and the dew point falls at night and is higher in the day. We'll look into this further later on in this document.

# %%
pollution_df["datetime"] = pd.to_datetime(pollution_df[["year", "month", "day", "hour"]])

dt = pollution_df["datetime"]
pollution_df.drop("datetime", axis=1, inplace=True)

# pollution_df.drop("year", axis = 1, inplace=True)
pollution_df.drop("month", axis = 1, inplace=True)
pollution_df.drop("day", axis = 1, inplace=True)
pollution_df.drop("hour", axis = 1, inplace=True)

# pollution_df.insert(0, pollution_df.pop(pollution_df.index("datetime")))
pollution_df.insert(0, "datetime", dt)

# %%
pollution_df.head(HEAD_COUNT)
# Out:
#               datetime  year  pm2.5  Dew  Temperature  Pressure  \
# No
# 1  2010-01-01 00:00:00  2010    NaN  -21        -11.0    1021.0
# 2  2010-01-01 01:00:00  2010    NaN  -21        -12.0    1020.0
# 3  2010-01-01 02:00:00  2010    NaN  -21        -11.0    1019.0
# 4  2010-01-01 03:00:00  2010    NaN  -21        -14.0    1019.0
# 5  2010-01-01 04:00:00  2010    NaN  -20        -12.0    1018.0
# 6  2010-01-01 05:00:00  2010    NaN  -19        -10.0    1017.0
# 7  2010-01-01 06:00:00  2010    NaN  -19         -9.0    1017.0
# 8  2010-01-01 07:00:00  2010    NaN  -19         -9.0    1017.0
# 9  2010-01-01 08:00:00  2010    NaN  -19         -9.0    1017.0
# 10 2010-01-01 09:00:00  2010    NaN  -20         -8.0    1017.0
#
#    Wind_Direction  Wind_Speed  Snow  Rain
# No
# 1              NW        1.79     0     0
# 2              NW        4.92     0     0
# 3              NW        6.71     0     0
# 4              NW        9.84     0     0
# 5              NW       12.97     0     0
# 6              NW       16.10     0     0
# 7              NW       19.23     0     0
# 8              NW       21.02     0     0
# 9              NW       24.15     0     0
# 10             NW       27.28     0     0

# %% [markdown]
# # Handling missing values
#
# ### Figuring out how many NaN values there are in the database.
#
# The empty values can either be dropped entirely, filled with 0's or filled with the mean. In this case, it will be filled with the mean values.
#
# There are **43824** records in total. Out of that, **2067** records are empty. For these records, they are filled by the mean of **pm2.5** values.

# %%
total_pm25_nan = sum(pd.isnull(pollution_df["pm2.5"]))
percentage_nan = total_pm25_nan / len(pollution_df["pm2.5"]) * 100

print("Number of empty values: {}.\nPercentage of empty values: {:.2f}%".format(total_pm25_nan, percentage_nan))
# Out:
# Number of empty values: 2067.
# Percentage of empty values: 4.72%

# %%
len(pollution_df["pm2.5"])
# Out:
# 43824

# %% [markdown]
# Find out which columns has NaN values. With this, we can see that **pm2.5** is the only column with actual missing **NaN** values.

# %%
pollution_df.isna().any()
# Out:
# datetime          False
# year              False
# pm2.5              True
# Dew               False
# Temperature       False
# Pressure          False
# Wind_Direction    False
# Wind_Speed        False
# Snow              False
# Rain              False
# dtype: bool

# %% [markdown]
# Fill out all missing **NaN** values with the mean.

# %%
empty_field_name = "pm2.5"

pollution_df[empty_field_name].fillna((pollution_df[empty_field_name].mean()), inplace=True)

# %%
pollution_df.head(HEAD_COUNT)
# Out:
#               datetime  year      pm2.5  Dew  Temperature  Pressure  \
# No
# 1  2010-01-01 00:00:00  2010  98.613215  -21        -11.0    1021.0
# 2  2010-01-01 01:00:00  2010  98.613215  -21        -12.0    1020.0
# 3  2010-01-01 02:00:00  2010  98.613215  -21        -11.0    1019.0
# 4  2010-01-01 03:00:00  2010  98.613215  -21        -14.0    1019.0
# 5  2010-01-01 04:00:00  2010  98.613215  -20        -12.0    1018.0
# 6  2010-01-01 05:00:00  2010  98.613215  -19        -10.0    1017.0
# 7  2010-01-01 06:00:00  2010  98.613215  -19         -9.0    1017.0
# 8  2010-01-01 07:00:00  2010  98.613215  -19         -9.0    1017.0
# 9  2010-01-01 08:00:00  2010  98.613215  -19         -9.0    1017.0
# 10 2010-01-01 09:00:00  2010  98.613215  -20         -8.0    1017.0
#
#    Wind_Direction  Wind_Speed  Snow  Rain
# No
# 1              NW        1.79     0     0
# 2              NW        4.92     0     0
# 3              NW        6.71     0     0
# 4              NW        9.84     0     0
# 5              NW       12.97     0     0
# 6              NW       16.10     0     0
# 7              NW       19.23     0     0
# 8              NW       21.02     0     0
# 9              NW       24.15     0     0
# 10             NW       27.28     0     0

# %%
pollution_df.tail(HEAD_COUNT)
# Out:
#                  datetime  year  pm2.5  Dew  Temperature  Pressure  \
# No
# 43815 2014-12-31 14:00:00  2014    9.0  -27          1.0    1032.0
# 43816 2014-12-31 15:00:00  2014   11.0  -26          1.0    1032.0
# 43817 2014-12-31 16:00:00  2014    8.0  -23          0.0    1032.0
# 43818 2014-12-31 17:00:00  2014    9.0  -22         -1.0    1033.0
# 43819 2014-12-31 18:00:00  2014   10.0  -22         -2.0    1033.0
# 43820 2014-12-31 19:00:00  2014    8.0  -23         -2.0    1034.0
# 43821 2014-12-31 20:00:00  2014   10.0  -22         -3.0    1034.0
# 43822 2014-12-31 21:00:00  2014   10.0  -22         -3.0    1034.0
# 43823 2014-12-31 22:00:00  2014    8.0  -22         -4.0    1034.0
# 43824 2014-12-31 23:00:00  2014   12.0  -21         -3.0    1034.0
#
#       Wind_Direction  Wind_Speed  Snow  Rain
# No
# 43815             NW      196.21     0     0
# 43816             NW      205.15     0     0
# 43817             NW      214.09     0     0
# 43818             NW      221.24     0     0
# 43819             NW      226.16     0     0
# 43820             NW      231.97     0     0
# 43821             NW      237.78     0     0
# 43822             NW      242.70     0     0
# 43823             NW      246.72     0     0
# 43824             NW      249.85     0     0

# %% [markdown]
# ### Dropping Wind_Speed "cv" values
#
# The wind speed attribute with values **cv** should be treated as noisy input or null values. As a result, all rows with **cv** values will be dropped.
#
# We could have attempted to replace all these **cv** values with the **mode** of windirection but that would have increased the complexity of this task. As a result, it has been much easier to just drop the rows which has **cv** as the wind direction.

# %%
index_of_wd_cv = pollution_df[pollution_df["Wind_Direction"] == "cv" ].index

pollution_df.drop(index_of_wd_cv , inplace=True)

# %% [markdown]
# # One hot encode wind direction
#
# As the wind direction given is textual, we cannot use it to feed into the classifier. There are two / four options here:
#
# - Label encoding
#
# - Ordinal encoding
#
# - One-hot encoding
#
# - Dummy encoding
#
# I have chosen dummy encoding in this instance one-hot and dummy encoding is statisically much better to deal with than label encoding. As a lot of the values here are continuous, label encoding is not statiscally good to use in this instance. As dummy encoding is much discreet, in this instance, its better to stick to dummy and one-hot. I have used dummy encoding as it's very easy to do in pandas.

# %%
pollution_dummies = pd.get_dummies(pollution_df["Wind_Direction"])

pollution_df_dummy = pollution_df.drop("Wind_Direction", axis=1)
pollution_df_dummy = pollution_df_dummy.join(pollution_dummies)

pollution_df = pollution_df_dummy

pollution_df.head(HEAD_COUNT)
# Out:
#               datetime  year      pm2.5  Dew  Temperature  Pressure  \
# No
# 1  2010-01-01 00:00:00  2010  98.613215  -21        -11.0    1021.0
# 2  2010-01-01 01:00:00  2010  98.613215  -21        -12.0    1020.0
# 3  2010-01-01 02:00:00  2010  98.613215  -21        -11.0    1019.0
# 4  2010-01-01 03:00:00  2010  98.613215  -21        -14.0    1019.0
# 5  2010-01-01 04:00:00  2010  98.613215  -20        -12.0    1018.0
# 6  2010-01-01 05:00:00  2010  98.613215  -19        -10.0    1017.0
# 7  2010-01-01 06:00:00  2010  98.613215  -19         -9.0    1017.0
# 8  2010-01-01 07:00:00  2010  98.613215  -19         -9.0    1017.0
# 9  2010-01-01 08:00:00  2010  98.613215  -19         -9.0    1017.0
# 10 2010-01-01 09:00:00  2010  98.613215  -20         -8.0    1017.0
#
#     Wind_Speed  Snow  Rain  NE  NW  SE
# No
# 1         1.79     0     0   0   1   0
# 2         4.92     0     0   0   1   0
# 3         6.71     0     0   0   1   0
# 4         9.84     0     0   0   1   0
# 5        12.97     0     0   0   1   0
# 6        16.10     0     0   0   1   0
# 7        19.23     0     0   0   1   0
# 8        21.02     0     0   0   1   0
# 9        24.15     0     0   0   1   0
# 10       27.28     0     0   0   1   0

# %% [markdown]
# # Plots

# %%
FIGURE_SIZE = (13, 5)

# Pollution plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["pm2.5"])
plt.xlabel('Day count')
plt.ylabel('Pollution (pm2.5)')
plt.title('Pollution pm2.5 plot')

plt.show()

# %%
# Temperature plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Temperature"])
plt.xlabel('Day count')
plt.ylabel('Temperature')
plt.title('Temperature plot')

plt.show()

# %% [markdown]
# Over here, we can see that the **dew** and the **temperature** is very highly correlated by just looking at the two plots visually.

# %%
# Dew plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Dew"])
plt.xlabel('Day count')
plt.ylabel('Dew')
plt.title('Dew plot')

plt.show()

# %% [markdown]
# We can see that there are much higher windspeed spikes when the temperature is low. When the temperature is high, the wind speed tends to be much higher.

# %%
# Wind speed plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Wind_Speed"])
plt.xlabel('Day count')
plt.ylabel('Wind speed')
plt.title('Wind speed plot')

plt.show()

# %% [markdown]
# Its very clear visually that the pressure plot is **inversely-correlated** to the temperature and the dew plots. When the temperature is low, the pressue is high and vice versa.

# %%
# Pressure plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Pressure"])
plt.xlabel('Day count')
plt.ylabel('Pressure')
plt.title('Pressure plot')

plt.show()

# %%
# Snow plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Snow"])
plt.xlabel('Day count')
plt.ylabel('Snow (mm)')
plt.title('Snow plot')

plt.show()

# %% [markdown]
# There is a higher amount of both rain and snow during high-pressure systems when the temperature is lower.

# %%
# Rain plot
plt.figure(figsize=FIGURE_SIZE)
plt.plot(pollution_df.index.values, pollution_df["Rain"])
plt.xlabel('Day count')
plt.ylabel('Rain (mm)')
plt.title('Rain plot')

plt.show()

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn import cross_validation
from sklearn.linear_model import LinearRegression
# Out:
# D:\Applications\Python3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### b) Frame the task as the supervised learning problem as predicting the pollution at the current hour given the pollution measurement and weather conditions at the previous hour. Using the first 4 years' data as the training set and the remaining 1 year's data as the test set. Prepare the training/test sets accordingly.

# %%
from sklearn import preprocessing

# write your code here

pollution_df.head(HEAD_COUNT)

p_train_index = pollution_df[pollution_df["year"] < 2014].index
p_test_index = pollution_df[pollution_df["year"] == 2014].index

p_train = pollution_df.drop(p_test_index)
p_test = pollution_df.drop(p_train_index)

# %%
p_train.head(HEAD_COUNT)
# Out:
#               datetime  year      pm2.5  Dew  Temperature  Pressure  \
# No
# 1  2010-01-01 00:00:00  2010  98.613215  -21        -11.0    1021.0
# 2  2010-01-01 01:00:00  2010  98.613215  -21        -12.0    1020.0
# 3  2010-01-01 02:00:00  2010  98.613215  -21        -11.0    1019.0
# 4  2010-01-01 03:00:00  2010  98.613215  -21        -14.0    1019.0
# 5  2010-01-01 04:00:00  2010  98.613215  -20        -12.0    1018.0
# 6  2010-01-01 05:00:00  2010  98.613215  -19        -10.0    1017.0
# 7  2010-01-01 06:00:00  2010  98.613215  -19         -9.0    1017.0
# 8  2010-01-01 07:00:00  2010  98.613215  -19         -9.0    1017.0
# 9  2010-01-01 08:00:00  2010  98.613215  -19         -9.0    1017.0
# 10 2010-01-01 09:00:00  2010  98.613215  -20         -8.0    1017.0
#
#     Wind_Speed  Snow  Rain  NE  NW  SE
# No
# 1         1.79     0     0   0   1   0
# 2         4.92     0     0   0   1   0
# 3         6.71     0     0   0   1   0
# 4         9.84     0     0   0   1   0
# 5        12.97     0     0   0   1   0
# 6        16.10     0     0   0   1   0
# 7        19.23     0     0   0   1   0
# 8        21.02     0     0   0   1   0
# 9        24.15     0     0   0   1   0
# 10       27.28     0     0   0   1   0

# %%
p_test.head(HEAD_COUNT)
# Out:
#                  datetime  year  pm2.5  Dew  Temperature  Pressure  \
# No
# 35065 2014-01-01 00:00:00  2014   24.0  -20          7.0    1014.0
# 35066 2014-01-01 01:00:00  2014   53.0  -20          7.0    1013.0
# 35067 2014-01-01 02:00:00  2014   65.0  -20          6.0    1013.0
# 35068 2014-01-01 03:00:00  2014   70.0  -20          6.0    1013.0
# 35070 2014-01-01 05:00:00  2014   92.0  -18          4.0    1012.0
# 35071 2014-01-01 06:00:00  2014  106.0  -19          6.0    1012.0
# 35072 2014-01-01 07:00:00  2014   75.0  -19          6.0    1013.0
# 35073 2014-01-01 08:00:00  2014   58.0  -18          6.0    1013.0
# 35074 2014-01-01 09:00:00  2014   33.0  -18          7.0    1014.0
# 35075 2014-01-01 10:00:00  2014   51.0  -18          8.0    1015.0
#
#        Wind_Speed  Snow  Rain  NE  NW  SE
# No
# 35065      143.48     0     0   0   1   0
# 35066      147.50     0     0   0   1   0
# 35067      151.52     0     0   0   1   0
# 35068      153.31     0     0   0   1   0
# 35070        4.02     0     0   0   1   0
# 35071        8.94     0     0   0   1   0
# 35072       16.09     0     0   0   1   0
# 35073       21.90     0     0   0   1   0
# 35074       26.82     0     0   0   1   0
# 35075       31.74     0     0   0   1   0

# %% [markdown]
# The heads of the train and test dataset is printed to ensure the split has happened correctly. **2010** to **2013** for train and **2014** for test.
#
# **Train set: p_train**<br>
# **Test set: p_test**

# %%
x_train_p = p_train.drop(columns=["datetime", "year"])
x_test_p = p_test.drop(columns=["datetime", "year"])

# %% [markdown]
# ### Scaling all the columns
#
# Scaling is applied to both the **x_train** and **x_test** to make **x_train_scaled** and **x_test_scaled**.
#
# For this, I have used two different scalers. One scaler is for the while dataframe and the other one is just for a dataframe with just the **pm2.5** value. The second scaler is created to allow for the inverse-transform of the scaled results to the actual values in the final step of the process so that the RMSE can be calculated.
#
# As there are significantly scaling difference in things like the temperature versus the pressure, the training is much faster and better when their values are scaled to a much more suitable amount.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

x_train_test_total = x_train_p.append(x_test_p)

scaler = StandardScaler().fit(x_train_test_total)
pm25_scaler = StandardScaler().fit(x_train_test_total["pm2.5"])

x_train_scaled = pd.DataFrame(scaler.transform(x_train_p), columns=x_train_p.columns)
x_test_scaled = pd.DataFrame(scaler.transform(x_test_p), columns=x_test_p.columns)
# Out:
# D:\Applications\Python3\lib\site-packages\sklearn\preprocessing\data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
x_train_scaled.head(HEAD_COUNT)
# Out:
#       pm2.5       Dew  Temperature  Pressure  Wind_Speed      Snow      Rain  \
# 0  0.083099 -1.502890    -1.896999  0.423379   -0.510659 -0.073355 -0.140993
# 1  0.083099 -1.502890    -1.977796  0.327938   -0.453626 -0.073355 -0.140993
# 2  0.083099 -1.502890    -1.896999  0.232497   -0.421010 -0.073355 -0.140993
# 3  0.083099 -1.502890    -2.139389  0.232497   -0.363977 -0.073355 -0.140993
# 4  0.083099 -1.434991    -1.977796  0.137056   -0.306945 -0.073355 -0.140993
# 5  0.083099 -1.367093    -1.816203  0.041615   -0.249912 -0.073355 -0.140993
# 6  0.083099 -1.367093    -1.735406  0.041615   -0.192879 -0.073355 -0.140993
# 7  0.083099 -1.367093    -1.735406  0.041615   -0.160263 -0.073355 -0.140993
# 8  0.083099 -1.367093    -1.735406  0.041615   -0.103231 -0.073355 -0.140993
# 9  0.083099 -1.434991    -1.654610  0.041615   -0.046198 -0.073355 -0.140993
#
#          NE        NW        SE
# 0 -0.411989  1.197376 -0.893621
# 1 -0.411989  1.197376 -0.893621
# 2 -0.411989  1.197376 -0.893621
# 3 -0.411989  1.197376 -0.893621
# 4 -0.411989  1.197376 -0.893621
# 5 -0.411989  1.197376 -0.893621
# 6 -0.411989  1.197376 -0.893621
# 7 -0.411989  1.197376 -0.893621
# 8 -0.411989  1.197376 -0.893621
# 9 -0.411989  1.197376 -0.893621

# %%
x_test_scaled.head(HEAD_COUNT)
# Out:
#       pm2.5       Dew  Temperature  Pressure  Wind_Speed      Snow      Rain  \
# 0 -0.783787 -1.434991    -0.442662 -0.244708    2.071115 -0.073355 -0.140993
# 1 -0.446853 -1.434991    -0.442662 -0.340149    2.144365 -0.073355 -0.140993
# 2 -0.307432 -1.434991    -0.523459 -0.340149    2.217614 -0.073355 -0.140993
# 3 -0.249340 -1.434991    -0.523459 -0.340149    2.250231 -0.073355 -0.140993
# 4  0.006264 -1.299194    -0.685052 -0.435590   -0.470025 -0.073355 -0.140993
# 5  0.168922 -1.367093    -0.523459 -0.435590   -0.380376 -0.073355 -0.140993
# 6 -0.191249 -1.367093    -0.523459 -0.340149   -0.250094 -0.073355 -0.140993
# 7 -0.388761 -1.299194    -0.523459 -0.340149   -0.144229 -0.073355 -0.140993
# 8 -0.679221 -1.299194    -0.442662 -0.244708   -0.054580 -0.073355 -0.140993
# 9 -0.470090 -1.299194    -0.361866 -0.149267    0.035069 -0.073355 -0.140993
#
#          NE        NW        SE
# 0 -0.411989  1.197376 -0.893621
# 1 -0.411989  1.197376 -0.893621
# 2 -0.411989  1.197376 -0.893621
# 3 -0.411989  1.197376 -0.893621
# 4 -0.411989  1.197376 -0.893621
# 5 -0.411989  1.197376 -0.893621
# 6 -0.411989  1.197376 -0.893621
# 7 -0.411989  1.197376 -0.893621
# 8 -0.411989  1.197376 -0.893621
# 9 -0.411989  1.197376 -0.893621

# %%
# Sanity check to make sure their length is correct
print("train length: {}".format(len(x_train_scaled)))
print("test length: {}".format(len(x_test_scaled)))
# Out:
# train length: 27756
# test length: 6681

# %%
y_train = pd.DataFrame(x_train_scaled["pm2.5"].shift(periods=-1))
y_test = pd.DataFrame(x_test_scaled["pm2.5"].shift(periods=-1))

# %% [markdown]
# #### Preparing the training data
#
# The prepation step involes shifting the **pm2.5** by -1 which moves up the value of pm2.5 by one compared to the result of the weather and previous pm2.5 data.
#
# Removing the last element of all the train and test sets as it's NaN for the pm2.5 and this will cause errorneous input

# %%
x_train_scaled = x_train_scaled[:-1]
x_test_scaled = x_test_scaled[:-1]

y_train = y_train[:-1]
y_test = y_test[:-1]

# %%
x_train = x_train_scaled.values
x_test = x_test_scaled.values

y_train = y_train.values
y_test = y_test.values

# %%
from sklearn.model_selection import train_test_split

VAL_SIZE = 0.1

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = VAL_SIZE, random_state=200)

# train_val_set = x_train_scaled
# train_val_set["y"] = y_train

# test_set = x_test_scaled
# test_set["y"] = y_test

# %%
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

# %% [markdown]
# ### c) Train a Recurrent Neural Network (RNN) on the training set. You can split the training set further by using 10% of the data as the validation set and the remaining for training.
#
#
# #### Architecture
#
# As this is a regression task with RNNs, I have used one RNN Layer with LSTM cell with 400 neurons. The data has been reshaped in the previous note which allows for one time step. This is required for all inputs going into LSTM cells as it shows the number of timesteps being used.
#
# The two-layer neural network is a Dense Layer without any activation function. This has only one neuron as there is only one single output. This output is the **scaled** predicted value. To see the actual value, this needs to be **inverse-transformed**.
#
# The loss function is **mean-squared-error** which measures the distance from the actual value to the predicted value.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, Dropout

FIGURE_SIZE = (13, 4)

BATCH_SIZE = 512
EPOCHS = 200

# write your code here
# design network
model = Sequential()

model.add(LSTM(400, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_val, y_val), verbose=2, shuffle=False)
# Out:
# Train on 24979 samples, validate on 2776 samples
# Epoch 1/200
#  - 3s - loss: 0.5688 - val_loss: 0.2354
# Epoch 2/200
#  - 0s - loss: 0.1457 - val_loss: 0.1041
# Epoch 3/200
#  - 0s - loss: 0.1133 - val_loss: 0.0978
# Epoch 4/200
#  - 0s - loss: 0.1101 - val_loss: 0.0964
# Epoch 5/200
#  - 0s - loss: 0.1089 - val_loss: 0.0959
# Epoch 6/200
#  - 0s - loss: 0.1083 - val_loss: 0.0956
# Epoch 7/200
#  - 0s - loss: 0.1080 - val_loss: 0.0956
# Epoch 8/200
#  - 0s - loss: 0.1078 - val_loss: 0.0956
# Epoch 9/200
#  - 0s - loss: 0.1077 - val_loss: 0.0956
# Epoch 10/200
#  - 0s - loss: 0.1076 - val_loss: 0.0955
# Epoch 11/200
#  - 0s - loss: 0.1075 - val_loss: 0.0955
# Epoch 12/200
#  - 0s - loss: 0.1075 - val_loss: 0.0955
# Epoch 13/200
#  - 0s - loss: 0.1075 - val_loss: 0.0955
# Epoch 14/200
#  - 0s - loss: 0.1074 - val_loss: 0.0955
# Epoch 15/200
#  - 0s - loss: 0.1074 - val_loss: 0.0955
# Epoch 16/200
#  - 0s - loss: 0.1074 - val_loss: 0.0954
# Epoch 17/200
#  - 0s - loss: 0.1074 - val_loss: 0.0954
# Epoch 18/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 19/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 20/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 21/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 22/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 23/200
#  - 0s - loss: 0.1073 - val_loss: 0.0954
# Epoch 24/200
#  - 0s - loss: 0.1072 - val_loss: 0.0954
# Epoch 25/200
#  - 0s - loss: 0.1072 - val_loss: 0.0953
# Epoch 26/200
#  - 0s - loss: 0.1072 - val_loss: 0.0953
# Epoch 27/200
#  - 0s - loss: 0.1072 - val_loss: 0.0953
# Epoch 28/200
#  - 0s - loss: 0.1072 - val_loss: 0.0953
# Epoch 29/200
#  - 0s - loss: 0.1072 - val_loss: 0.0953
# Epoch 30/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 31/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 32/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 33/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 34/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 35/200
#  - 0s - loss: 0.1071 - val_loss: 0.0953
# Epoch 36/200
#  - 0s - loss: 0.1070 - val_loss: 0.0953
# Epoch 37/200
#  - 0s - loss: 0.1070 - val_loss: 0.0953
# Epoch 38/200
#  - 0s - loss: 0.1070 - val_loss: 0.0953
# Epoch 39/200
#  - 0s - loss: 0.1070 - val_loss: 0.0953
# Epoch 40/200
#  - 0s - loss: 0.1070 - val_loss: 0.0953
# Epoch 41/200
#  - 0s - loss: 0.1069 - val_loss: 0.0953
# Epoch 42/200
#  - 0s - loss: 0.1069 - val_loss: 0.0953
# Epoch 43/200
#  - 0s - loss: 0.1069 - val_loss: 0.0953
# Epoch 44/200
#  - 0s - loss: 0.1069 - val_loss: 0.0953
# Epoch 45/200
#  - 0s - loss: 0.1068 - val_loss: 0.0953
# Epoch 46/200
#  - 0s - loss: 0.1068 - val_loss: 0.0953
# Epoch 47/200
#  - 0s - loss: 0.1068 - val_loss: 0.0954
# Epoch 48/200
#  - 0s - loss: 0.1068 - val_loss: 0.0954
# Epoch 49/200
#  - 0s - loss: 0.1068 - val_loss: 0.0954
# Epoch 50/200
#  - 0s - loss: 0.1067 - val_loss: 0.0954
# Epoch 51/200
#  - 0s - loss: 0.1067 - val_loss: 0.0954
# Epoch 52/200
#  - 0s - loss: 0.1067 - val_loss: 0.0954
# Epoch 53/200
#  - 0s - loss: 0.1067 - val_loss: 0.0954
# Epoch 54/200
#  - 0s - loss: 0.1066 - val_loss: 0.0954
# Epoch 55/200
#  - 0s - loss: 0.1066 - val_loss: 0.0955
# Epoch 56/200
#  - 0s - loss: 0.1066 - val_loss: 0.0955
# Epoch 57/200
#  - 0s - loss: 0.1066 - val_loss: 0.0955
# Epoch 58/200
#  - 0s - loss: 0.1066 - val_loss: 0.0955
# Epoch 59/200
#  - 0s - loss: 0.1065 - val_loss: 0.0955
# Epoch 60/200
#  - 0s - loss: 0.1065 - val_loss: 0.0955
# Epoch 61/200
#  - 0s - loss: 0.1065 - val_loss: 0.0955
# Epoch 62/200
#  - 0s - loss: 0.1065 - val_loss: 0.0955
# Epoch 63/200
#  - 0s - loss: 0.1064 - val_loss: 0.0955
# Epoch 64/200
#  - 0s - loss: 0.1064 - val_loss: 0.0955
# Epoch 65/200
#  - 0s - loss: 0.1064 - val_loss: 0.0955
# Epoch 66/200
#  - 0s - loss: 0.1064 - val_loss: 0.0955
# Epoch 67/200
#  - 0s - loss: 0.1064 - val_loss: 0.0956
# Epoch 68/200
#  - 0s - loss: 0.1064 - val_loss: 0.0956
# Epoch 69/200
#  - 0s - loss: 0.1063 - val_loss: 0.0956
# Epoch 70/200
#  - 0s - loss: 0.1063 - val_loss: 0.0956
# Epoch 71/200
#  - 0s - loss: 0.1063 - val_loss: 0.0956
# Epoch 72/200
#  - 0s - loss: 0.1063 - val_loss: 0.0956
# Epoch 73/200
#  - 0s - loss: 0.1063 - val_loss: 0.0956
# Epoch 74/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 75/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 76/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 77/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 78/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 79/200
#  - 0s - loss: 0.1062 - val_loss: 0.0956
# Epoch 80/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 81/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 82/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 83/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 84/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 85/200
#  - 0s - loss: 0.1061 - val_loss: 0.0956
# Epoch 86/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 87/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 88/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 89/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 90/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 91/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 92/200
#  - 0s - loss: 0.1060 - val_loss: 0.0956
# Epoch 93/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 94/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 95/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 96/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 97/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 98/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 99/200
#  - 0s - loss: 0.1059 - val_loss: 0.0956
# Epoch 100/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 101/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 102/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 103/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 104/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 105/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 106/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 107/200
#  - 0s - loss: 0.1058 - val_loss: 0.0956
# Epoch 108/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 109/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 110/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 111/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 112/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 113/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 114/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 115/200
#  - 0s - loss: 0.1057 - val_loss: 0.0956
# Epoch 116/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 117/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 118/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 119/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 120/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 121/200
#  - 0s - loss: 0.1056 - val_loss: 0.0956
# Epoch 122/200
#  - 0s - loss: 0.1056 - val_loss: 0.0955
# Epoch 123/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 124/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 125/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 126/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 127/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 128/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 129/200
#  - 0s - loss: 0.1055 - val_loss: 0.0955
# Epoch 130/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 131/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 132/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 133/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 134/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 135/200
#  - 0s - loss: 0.1054 - val_loss: 0.0954
# Epoch 136/200
#  - 0s - loss: 0.1053 - val_loss: 0.0954
# Epoch 137/200
#  - 0s - loss: 0.1053 - val_loss: 0.0954
# Epoch 138/200
#  - 0s - loss: 0.1053 - val_loss: 0.0953
# Epoch 139/200
#  - 0s - loss: 0.1053 - val_loss: 0.0953
# Epoch 140/200
#  - 0s - loss: 0.1053 - val_loss: 0.0953
# Epoch 141/200
#  - 0s - loss: 0.1053 - val_loss: 0.0953
# Epoch 142/200
#  - 0s - loss: 0.1053 - val_loss: 0.0953
# Epoch 143/200
#  - 0s - loss: 0.1052 - val_loss: 0.0953
# Epoch 144/200
#  - 0s - loss: 0.1052 - val_loss: 0.0953
# Epoch 145/200
#  - 0s - loss: 0.1052 - val_loss: 0.0953
# Epoch 146/200
#  - 0s - loss: 0.1052 - val_loss: 0.0952
# Epoch 147/200
#  - 0s - loss: 0.1052 - val_loss: 0.0952
# Epoch 148/200
#  - 0s - loss: 0.1052 - val_loss: 0.0952
# Epoch 149/200
#  - 0s - loss: 0.1051 - val_loss: 0.0952
# Epoch 150/200
#  - 0s - loss: 0.1051 - val_loss: 0.0952
# Epoch 151/200
#  - 0s - loss: 0.1051 - val_loss: 0.0952
# Epoch 152/200
#  - 0s - loss: 0.1051 - val_loss: 0.0952
# Epoch 153/200
#  - 0s - loss: 0.1051 - val_loss: 0.0952
# Epoch 154/200
#  - 0s - loss: 0.1051 - val_loss: 0.0951
# Epoch 155/200
#  - 0s - loss: 0.1050 - val_loss: 0.0951
# Epoch 156/200
#  - 0s - loss: 0.1050 - val_loss: 0.0951
# Epoch 157/200
#  - 0s - loss: 0.1050 - val_loss: 0.0951
# Epoch 158/200
#  - 0s - loss: 0.1050 - val_loss: 0.0951
# Epoch 159/200
#  - 0s - loss: 0.1050 - val_loss: 0.0951
# Epoch 160/200
#  - 0s - loss: 0.1050 - val_loss: 0.0950
# Epoch 161/200
#  - 0s - loss: 0.1049 - val_loss: 0.0950
# Epoch 162/200
#  - 0s - loss: 0.1049 - val_loss: 0.0950
# Epoch 163/200
#  - 0s - loss: 0.1049 - val_loss: 0.0950
# Epoch 164/200
#  - 0s - loss: 0.1049 - val_loss: 0.0950
# Epoch 165/200
#  - 0s - loss: 0.1049 - val_loss: 0.0950
# Epoch 166/200
#  - 0s - loss: 0.1049 - val_loss: 0.0949
# Epoch 167/200
#  - 0s - loss: 0.1048 - val_loss: 0.0949
# Epoch 168/200
#  - 0s - loss: 0.1048 - val_loss: 0.0949
# Epoch 169/200
#  - 0s - loss: 0.1048 - val_loss: 0.0949
# Epoch 170/200
#  - 0s - loss: 0.1048 - val_loss: 0.0949
# Epoch 171/200
#  - 0s - loss: 0.1048 - val_loss: 0.0949
# Epoch 172/200
#  - 0s - loss: 0.1048 - val_loss: 0.0948
# Epoch 173/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 174/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 175/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 176/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 177/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 178/200
#  - 0s - loss: 0.1047 - val_loss: 0.0948
# Epoch 179/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 180/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 181/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 182/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 183/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 184/200
#  - 0s - loss: 0.1046 - val_loss: 0.0947
# Epoch 185/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 186/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 187/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 188/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 189/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 190/200
#  - 0s - loss: 0.1045 - val_loss: 0.0946
# Epoch 191/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 192/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 193/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 194/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 195/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 196/200
#  - 0s - loss: 0.1044 - val_loss: 0.0945
# Epoch 197/200
#  - 0s - loss: 0.1044 - val_loss: 0.0944
# Epoch 198/200
#  - 0s - loss: 0.1043 - val_loss: 0.0944
# Epoch 199/200
#  - 0s - loss: 0.1043 - val_loss: 0.0944
# Epoch 200/200
#  - 0s - loss: 0.1043 - val_loss: 0.0944

# %% [markdown]
# The plot below shows the training and the test losses

# %% [markdown]
# #### Loss plot
#
# This is the whole loss plot. The loss drops significantly at the start and then stays fairly stable.
#
# The second plot is the plot of the same data but with the first 10 epochs omitted. As the loss drops so quickly in the first 10 epochs, the scaling is much better to look at in the second one.
#
# We can see that the training loss decreases overtime but the validation loss fluctuates a little without much improvement.

# %%
# plot history
plt.figure(figsize=FIGURE_SIZE)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(history.history['loss'][10:], label='train')
plt.plot(history.history['val_loss'][10:], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### d) Output the prediction results such as Root Mean Squared Errors (RMSE) on the test set. Remember that after the forecasts have been made, we need to invert the transforms to return the values back into the original scale. This is needed so that we can calculate error scores and plots that are comparable with other models. Plot the predicted values vs. the actual values.

# %%
from sklearn.metrics import mean_squared_error

# write your code here

# %%
def predict_and_score(_model, x, y):
    # Make predictions on the original scale of the data.
    y_hat = _model.predict(x)
    
    pred = pm25_scaler.inverse_transform(y_hat)
    y_inv_scaled = pm25_scaler.inverse_transform(y)
    
    x_actual_inv_scaled = scaler.inverse_transform(x)
    x_actual_inv_scaled = x_actual_inv_scaled.T[0].T
  
    score = math.sqrt(mean_squared_error(y_inv_scaled, pred))
    
    return(score, pred, x_actual_inv_scaled)

# %% [markdown]
# ### Results
#
# The RMSE shows the standard deviation of the actual values from the predicted results. THis means that the rmse value is that much likely to be deviated from the actual results.

# %%
rmse_train, train_predict, train_actual = predict_and_score(model, x_train, y_train)
rmse_test, test_predict, test_actual = predict_and_score(model, x_test, y_test)

# %%
print("RMSE Train: {}".format(rmse_train))
print("RMSE Test: {}".format(rmse_test))
# Out:
# RMSE Train: 27.738051984631042
# RMSE Test: 26.591809135359576

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(train_actual, label='actual')
plt.plot(train_predict, label='predicted')

plt.legend()
plt.show()

# %% [markdown]
# #### Train vs Actual plot
#
# The graph below is the scatter plot between the train and the predicted values of the pollution. This is fairly straight with very few outliers meaning it's quie good.
#
# In the best case scenario without any errors, all the plots should be on a straight line of the equation of **y = x**. We can see from the plot that it's not the case. There is a bit of variance on the line and it's gradient is not **1**. However, its fairly close and tightly knit together. This shows a good result.

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.scatter(train_actual,train_predict,  label='actual')
# plt.plot(label='predicted')

plt.legend()
plt.show()

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(train_predict, label='predicted')
plt.plot(train_actual, label='actual')

plt.legend()
plt.show()

# %% [markdown]
# ### e) Explore different network architectures (e.g., stacked LSTM layers) and various ways in tuning the model parameters to see if you can improve the model performance on the test set.
#
#
# Over here, I have used 4 LSTM layers with BatchNorm and Dropout (0.2). After flattening out the results, I have used 3 Dense Layers with neurons (500, 500, 200) with one single-neuron Dense Layer for the final output of the results.

# %%
EPOCHS=120
BATCH_SIZE = 512

model_complex = Sequential()
model_complex.add(LSTM(400, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.2))

model_complex.add(LSTM(400, return_sequences=True))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.2))

model_complex.add(LSTM(400, return_sequences=True))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.2))

model_complex.add(LSTM(400, activation='relu'))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.2))

model_complex.add(Dense(500))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.1))

model_complex.add(Dense(500))
model_complex.add(BatchNormalization())
model_complex.add(Activation('relu'))
model_complex.add(Dropout(0.1))

model_complex.add(Dense(20))

model_complex.add(Dense(1))


model_complex.compile(loss='mse', optimizer='adam')

# fit network
history = model_complex.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_val, y_val), verbose=2, shuffle=False)
# Out:
# Train on 24979 samples, validate on 2776 samples
# Epoch 1/120
#  - 7s - loss: 1.0264 - val_loss: 1.0922
# Epoch 2/120
#  - 2s - loss: 0.3045 - val_loss: 0.2676
# Epoch 3/120
#  - 2s - loss: 0.2123 - val_loss: 0.1540
# Epoch 4/120
#  - 2s - loss: 0.1904 - val_loss: 0.1602
# Epoch 5/120
#  - 2s - loss: 0.1729 - val_loss: 0.1248
# Epoch 6/120
#  - 2s - loss: 0.1589 - val_loss: 0.1214
# Epoch 7/120
#  - 2s - loss: 0.1518 - val_loss: 0.1126
# Epoch 8/120
#  - 2s - loss: 0.1482 - val_loss: 0.1142
# Epoch 9/120
#  - 2s - loss: 0.1511 - val_loss: 0.1142
# Epoch 10/120
#  - 2s - loss: 0.1478 - val_loss: 0.1098
# Epoch 11/120
#  - 2s - loss: 0.1465 - val_loss: 0.1103
# Epoch 12/120
#  - 2s - loss: 0.1452 - val_loss: 0.1056
# Epoch 13/120
#  - 2s - loss: 0.1445 - val_loss: 0.1042
# Epoch 14/120
#  - 2s - loss: 0.1423 - val_loss: 0.1062
# Epoch 15/120
#  - 2s - loss: 0.1416 - val_loss: 0.1072
# Epoch 16/120
#  - 2s - loss: 0.1427 - val_loss: 0.1070
# Epoch 17/120
#  - 2s - loss: 0.1380 - val_loss: 0.1130
# Epoch 18/120
#  - 2s - loss: 0.1361 - val_loss: 0.1033
# Epoch 19/120
#  - 2s - loss: 0.1346 - val_loss: 0.1139
# Epoch 20/120
#  - 2s - loss: 0.1370 - val_loss: 0.1137
# Epoch 21/120
#  - 2s - loss: 0.1338 - val_loss: 0.1209
# Epoch 22/120
#  - 2s - loss: 0.1337 - val_loss: 0.1098
# Epoch 23/120
#  - 2s - loss: 0.1327 - val_loss: 0.1057
# Epoch 24/120
#  - 2s - loss: 0.1334 - val_loss: 0.1060
# Epoch 25/120
#  - 2s - loss: 0.1325 - val_loss: 0.1121
# Epoch 26/120
#  - 2s - loss: 0.1341 - val_loss: 0.1019
# Epoch 27/120
#  - 2s - loss: 0.1341 - val_loss: 0.1092
# Epoch 28/120
#  - 2s - loss: 0.1310 - val_loss: 0.1047
# Epoch 29/120
#  - 2s - loss: 0.1305 - val_loss: 0.1157
# Epoch 30/120
#  - 2s - loss: 0.1304 - val_loss: 0.1098
# Epoch 31/120
#  - 2s - loss: 0.1284 - val_loss: 0.1014
# Epoch 32/120
#  - 2s - loss: 0.1299 - val_loss: 0.1190
# Epoch 33/120
#  - 2s - loss: 0.1289 - val_loss: 0.1033
# Epoch 34/120
#  - 2s - loss: 0.1287 - val_loss: 0.1169
# Epoch 35/120
#  - 2s - loss: 0.1294 - val_loss: 0.1146
# Epoch 36/120
#  - 2s - loss: 0.1265 - val_loss: 0.0997
# Epoch 37/120
#  - 2s - loss: 0.1268 - val_loss: 0.1024
# Epoch 38/120
#  - 2s - loss: 0.1267 - val_loss: 0.1125
# Epoch 39/120
#  - 2s - loss: 0.1264 - val_loss: 0.1170
# Epoch 40/120
#  - 2s - loss: 0.1266 - val_loss: 0.1119
# Epoch 41/120
#  - 2s - loss: 0.1262 - val_loss: 0.1238
# Epoch 42/120
#  - 2s - loss: 0.1273 - val_loss: 0.1270
# Epoch 43/120
#  - 2s - loss: 0.1289 - val_loss: 0.1130
# Epoch 44/120
#  - 2s - loss: 0.1260 - val_loss: 0.1213
# Epoch 45/120
#  - 2s - loss: 0.1277 - val_loss: 0.1102
# Epoch 46/120
#  - 2s - loss: 0.1273 - val_loss: 0.1225
# Epoch 47/120
#  - 2s - loss: 0.1238 - val_loss: 0.1137
# Epoch 48/120
#  - 2s - loss: 0.1247 - val_loss: 0.0991
# Epoch 49/120
#  - 2s - loss: 0.1257 - val_loss: 0.1196
# Epoch 50/120
#  - 2s - loss: 0.1244 - val_loss: 0.1123
# Epoch 51/120
#  - 2s - loss: 0.1251 - val_loss: 0.1050
# Epoch 52/120
#  - 2s - loss: 0.1270 - val_loss: 0.1033
# Epoch 53/120
#  - 2s - loss: 0.1255 - val_loss: 0.1081
# Epoch 54/120
#  - 2s - loss: 0.1258 - val_loss: 0.1375
# Epoch 55/120
#  - 2s - loss: 0.1246 - val_loss: 0.1042
# Epoch 56/120
#  - 2s - loss: 0.1248 - val_loss: 0.1052
# Epoch 57/120
#  - 2s - loss: 0.1230 - val_loss: 0.1161
# Epoch 58/120
#  - 2s - loss: 0.1249 - val_loss: 0.1036
# Epoch 59/120
#  - 2s - loss: 0.1249 - val_loss: 0.1099
# Epoch 60/120
#  - 2s - loss: 0.1211 - val_loss: 0.1063
# Epoch 61/120
#  - 2s - loss: 0.1234 - val_loss: 0.1161
# Epoch 62/120
#  - 2s - loss: 0.1219 - val_loss: 0.1018
# Epoch 63/120
#  - 2s - loss: 0.1218 - val_loss: 0.0986
# Epoch 64/120
#  - 2s - loss: 0.1220 - val_loss: 0.1036
# Epoch 65/120
#  - 2s - loss: 0.1224 - val_loss: 0.1068
# Epoch 66/120
#  - 2s - loss: 0.1214 - val_loss: 0.1003
# Epoch 67/120
#  - 2s - loss: 0.1240 - val_loss: 0.1040
# Epoch 68/120
#  - 2s - loss: 0.1215 - val_loss: 0.1093
# Epoch 69/120
#  - 2s - loss: 0.1218 - val_loss: 0.1069
# Epoch 70/120
#  - 2s - loss: 0.1219 - val_loss: 0.1054
# Epoch 71/120
#  - 2s - loss: 0.1213 - val_loss: 0.1067
# Epoch 72/120
#  - 2s - loss: 0.1209 - val_loss: 0.1006
# Epoch 73/120
#  - 2s - loss: 0.1220 - val_loss: 0.1068
# Epoch 74/120
#  - 2s - loss: 0.1202 - val_loss: 0.1024
# Epoch 75/120
#  - 2s - loss: 0.1223 - val_loss: 0.1039
# Epoch 76/120
#  - 2s - loss: 0.1221 - val_loss: 0.1025
# Epoch 77/120
#  - 2s - loss: 0.1230 - val_loss: 0.1023
# Epoch 78/120
#  - 2s - loss: 0.1182 - val_loss: 0.1008
# Epoch 79/120
#  - 2s - loss: 0.1214 - val_loss: 0.1038
# Epoch 80/120
#  - 2s - loss: 0.1188 - val_loss: 0.1013
# Epoch 81/120
#  - 2s - loss: 0.1196 - val_loss: 0.1054
# Epoch 82/120
#  - 2s - loss: 0.1177 - val_loss: 0.1008
# Epoch 83/120
#  - 2s - loss: 0.1223 - val_loss: 0.1081
# Epoch 84/120
#  - 2s - loss: 0.1217 - val_loss: 0.1028
# Epoch 85/120
#  - 2s - loss: 0.1178 - val_loss: 0.1012
# Epoch 86/120
#  - 2s - loss: 0.1197 - val_loss: 0.0975
# Epoch 87/120
#  - 2s - loss: 0.1191 - val_loss: 0.1191
# Epoch 88/120
#  - 2s - loss: 0.1230 - val_loss: 0.1031
# Epoch 89/120
#  - 2s - loss: 0.1217 - val_loss: 0.1009
# Epoch 90/120
#  - 2s - loss: 0.1195 - val_loss: 0.1019
# Epoch 91/120
#  - 2s - loss: 0.1176 - val_loss: 0.1038
# Epoch 92/120
#  - 2s - loss: 0.1177 - val_loss: 0.0980
# Epoch 93/120
#  - 2s - loss: 0.1167 - val_loss: 0.0977
# Epoch 94/120
#  - 2s - loss: 0.1180 - val_loss: 0.1052
# Epoch 95/120
#  - 2s - loss: 0.1158 - val_loss: 0.0988
# Epoch 96/120
#  - 2s - loss: 0.1177 - val_loss: 0.1070
# Epoch 97/120
#  - 2s - loss: 0.1148 - val_loss: 0.1028
# Epoch 98/120
#  - 2s - loss: 0.1146 - val_loss: 0.1022
# Epoch 99/120
#  - 2s - loss: 0.1142 - val_loss: 0.1047
# Epoch 100/120
#  - 2s - loss: 0.1147 - val_loss: 0.1002
# Epoch 101/120
#  - 2s - loss: 0.1138 - val_loss: 0.1035
# Epoch 102/120
#  - 2s - loss: 0.1140 - val_loss: 0.1048
# Epoch 103/120
#  - 2s - loss: 0.1166 - val_loss: 0.1004
# Epoch 104/120
#  - 2s - loss: 0.1150 - val_loss: 0.1077
# Epoch 105/120
#  - 2s - loss: 0.1141 - val_loss: 0.1067
# Epoch 106/120
#  - 2s - loss: 0.1127 - val_loss: 0.1066
# Epoch 107/120
#  - 2s - loss: 0.1125 - val_loss: 0.1024
# Epoch 108/120
#  - 2s - loss: 0.1111 - val_loss: 0.0980
# Epoch 109/120
#  - 2s - loss: 0.1140 - val_loss: 0.0980
# Epoch 110/120
#  - 2s - loss: 0.1134 - val_loss: 0.0991
# Epoch 111/120
#  - 2s - loss: 0.1113 - val_loss: 0.0980
# Epoch 112/120
#  - 2s - loss: 0.1100 - val_loss: 0.1005
# Epoch 113/120
#  - 2s - loss: 0.1143 - val_loss: 0.1102
# Epoch 114/120
#  - 2s - loss: 0.1149 - val_loss: 0.1013
# Epoch 115/120
#  - 2s - loss: 0.1106 - val_loss: 0.1023
# Epoch 116/120
#  - 2s - loss: 0.1111 - val_loss: 0.1006
# Epoch 117/120
#  - 2s - loss: 0.1093 - val_loss: 0.1040
# Epoch 118/120
#  - 2s - loss: 0.1084 - val_loss: 0.0975
# Epoch 119/120
#  - 2s - loss: 0.1095 - val_loss: 0.0982
# Epoch 120/120
#  - 2s - loss: 0.1060 - val_loss: 0.1018

# %%
# write your code here
plt.figure(figsize=FIGURE_SIZE)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# The loss is spiking quite a lot. At around epoch 87, the test loss goes over the training loss.
#
# As the loss doesn't decrease much over time, its not learning much apart form the start. The lowest loss is at around epoch #40

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(history.history['loss'][10:], label='train')
plt.plot(history.history['val_loss'][10:], label='test')
plt.legend()
plt.show()

# %%
rmse_train, train_predict, train_actual = predict_and_score(model_complex, x_train, y_train)
rmse_test, test_predict, test_actual = predict_and_score(model_complex, x_test, y_test)

# %% [markdown]
# The RMSE for both of these is higher than the RMSe for the simple LSTM network.
#
# This shows that the simple LSTM network was acutally better.

# %%
print("RMSE Train: {}".format(rmse_train))
print("RMSE Test: {}".format(rmse_test))
# Out:
# RMSE Train: 27.027269781790803
# RMSE Test: 28.018359826836544

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(train_actual, label='actual')
plt.plot(train_predict, label='predicted')

plt.legend()
plt.show()

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(train_predict, label='predicted')
plt.plot(train_actual, label='actual')

plt.legend()
plt.show()

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(test_predict, label='predicted')
plt.plot(test_actual, label='actual')

plt.legend()
plt.show()

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.plot(test_actual, label='actual')
plt.plot(test_predict, label='predicted')

plt.legend()
plt.show()

# %% [markdown]
# Although the line is mostly straight, there are quite a few outliers on this line compared to the first neural network. This is also reflected by worse RMSE results.

# %%
plt.figure(figsize=FIGURE_SIZE)
plt.scatter(test_actual,test_predict, label='actual')

# plt.plot( label='predicted')

plt.legend()
plt.show()

# %% [markdown]
# ### f) Explore alterative prediction setup by predicting the pollution for the next hour based on the weather conditions and pollution over the last 3 days.

# %%
# write your code here
